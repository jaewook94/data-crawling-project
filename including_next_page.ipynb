# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import pyperclip
import urllib.request
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
from pprint import pprint

# %%
path = r'C:\Users\재욱\Downloads\chromedriver.exe'
driver = webdriver.Chrome(path)
country_url = "https://www.brandsoftheworld.com/logos/countries" 
driver.get(country_url)

xpath = '//*[@id="primaryInner"]/div/ul'
division = driver.find_element_by_xpath(xpath)
country_list = division.find_elements_by_tag_name('a') # List형

country_url_list = []
for country_url in country_list:
    country_url_list.append(country_url.get_attribute('href'))

# %%
country_url_list
# Out:
# ['https://www.brandsoftheworld.com/logos/countries/af',
#  'https://www.brandsoftheworld.com/logos/countries/al',
#  'https://www.brandsoftheworld.com/logos/countries/dz',
#  'https://www.brandsoftheworld.com/logos/countries/as',
#  'https://www.brandsoftheworld.com/logos/countries/ad',
#  'https://www.brandsoftheworld.com/logos/countries/ao',
#  'https://www.brandsoftheworld.com/logos/countries/ai',
#  'https://www.brandsoftheworld.com/logos/countries/aq',
#  'https://www.brandsoftheworld.com/logos/countries/ag',
#  'https://www.brandsoftheworld.com/logos/countries/ar',
#  'https://www.brandsoftheworld.com/logos/countries/am',
#  'https://www.brandsoftheworld.com/logos/countries/aw',
#  'https://www.brandsoftheworld.com/logos/countries/au',
#  'https://www.brandsoftheworld.com/logos/countries/at',
#  'https://www.brandsoftheworld.com/logos/countries/az',
#  'https://www.brandsoftheworld.com/logos/countries/bh',
#  'https://www.brandsoftheworld.com/logos/countries/bd',
#  'https://www.brandsoftheworld.com/logos/countries/bb',
#  'https://www.brandsoftheworld.com/logos/countries/by',
#  'https://www.brandsoftheworld.com/logos/countries/be',
#  'https://www.brandsoftheworld.com/logos/countries/bz',
#  'https://www.brandsoftheworld.com/logos/countries/bj',
#  'https://www.brandsoftheworld.com/logos/countries/bm',
#  'https://www.brandsoftheworld.com/logos/countries/bt',
#  'https://www.brandsoftheworld.com/logos/countries/bo',
#  'https://www.brandsoftheworld.com/logos/countries/ba',
#  'https://www.brandsoftheworld.com/logos/countries/bw',
#  'https://www.brandsoftheworld.com/logos/countries/bv',
#  'https://www.brandsoftheworld.com/logos/countries/br',
#  'https://www.brandsoftheworld.com/logos/countries/bn',
#  'https://www.brandsoftheworld.com/logos/countries/bg',
#  'https://www.brandsoftheworld.com/logos/countries/bf',
#  'https://www.brandsoftheworld.com/logos/countries/bi',
#  'https://www.brandsoftheworld.com/logos/countries/kh',
#  'https://www.brandsoftheworld.com/logos/countries/cm',
#  'https://www.brandsoftheworld.com/logos/countries/ca',
#  'https://www.brandsoftheworld.com/logos/countries/cv',
#  'https://www.brandsoftheworld.com/logos/countries/ky',
#  'https://www.brandsoftheworld.com/logos/countries/cf',
#  'https://www.brandsoftheworld.com/logos/countries/td',
#  'https://www.brandsoftheworld.com/logos/countries/cl',
#  'https://www.brandsoftheworld.com/logos/countries/cn',
#  'https://www.brandsoftheworld.com/logos/countries/cx',
#  'https://www.brandsoftheworld.com/logos/countries/cc',
#  'https://www.brandsoftheworld.com/logos/countries/sj',
#  'https://www.brandsoftheworld.com/logos/countries/sz',
#  'https://www.brandsoftheworld.com/logos/countries/se',
#  'https://www.brandsoftheworld.com/logos/countries/ch',
#  'https://www.brandsoftheworld.com/logos/countries/sy',
#  'https://www.brandsoftheworld.com/logos/countries/tw',
#  'https://www.brandsoftheworld.com/logos/countries/tj',
#  'https://www.brandsoftheworld.com/logos/countries/tz',
#  'https://www.brandsoftheworld.com/logos/countries/th',
#  'https://www.brandsoftheworld.com/logos/countries/bs',
#  'https://www.brandsoftheworld.com/logos/countries/tg',
#  'https://www.brandsoftheworld.com/logos/countries/tk',
#  'https://www.brandsoftheworld.com/logos/countries/to',
#  'https://www.brandsoftheworld.com/logos/countries/tt',
#  'https://www.brandsoftheworld.com/logos/countries/tn',
#  'https://www.brandsoftheworld.com/logos/countries/tc',
#  'https://www.brandsoftheworld.com/logos/countries/tr',
#  'https://www.brandsoftheworld.com/logos/countries/tm',
#  'https://www.brandsoftheworld.com/logos/countries/tv',
#  'https://www.brandsoftheworld.com/logos/countries/ug',
#  'https://www.brandsoftheworld.com/logos/countries/ua',
#  'https://www.brandsoftheworld.com/logos/countries/ae',
#  'https://www.brandsoftheworld.com/logos/countries/uk',
#  'https://www.brandsoftheworld.com/logos/countries/us',
#  'https://www.brandsoftheworld.com/logos/countries/uy',
#  'https://www.brandsoftheworld.com/logos/countries/uz',
#  'https://www.brandsoftheworld.com/logos/countries/vu',
#  'https://www.brandsoftheworld.com/logos/countries/va',
#  'https://www.brandsoftheworld.com/logos/countries/ve',
#  'https://www.brandsoftheworld.com/logos/countries/vn',
#  'https://www.brandsoftheworld.com/logos/countries/vi',
#  'https://www.brandsoftheworld.com/logos/countries/wf',
#  'https://www.brandsoftheworld.com/logos/countries/eh',
#  'https://www.brandsoftheworld.com/logos/countries/ye',
#  'https://www.brandsoftheworld.com/logos/countries/yu',
#  'https://www.brandsoftheworld.com/logos/countries/zr',
#  'https://www.brandsoftheworld.com/logos/countries/zm',
#  'https://www.brandsoftheworld.com/logos/countries/zw']

# %% [markdown]
# ## Old Code

# %%
XPATH_COUNTRY_TABLE = '//*[@id="primaryInner"]/div/div[1]'
XPATH_COUNTRY_NAME = '//*[@id="primary"]/h1/span'
for country_path in country_url_list:
    page_num = 0
    while True:
        driver.get(country_path + '?page=' + str(page_num))
        division = driver.find_element_by_xpath(XPATH_COUNTRY_TABLE) # 빼면 안됨
        name_list = division.find_elements_by_tag_name('li') # List형
        image_url_list = division.find_elements_by_tag_name('img') # List형
        
        company_name_list = []
        for name in name_list:
            company_name_list.append(name.text)
            
        # if company_name_list == ['« first', '‹ previous', '1', '2']:
        if len(image_url_list) == 0:
            break
        page_num +=1

        i = 0
        for image_url in image_url_list:
            try:
                with urllib.request.urlopen(image_url.get_attribute('src')) as f:
                    with open(img_folder_path + company_name_list[i] +'.jpg','wb') as h:
                        image = f.read()
                        h.write(image)
            except Exception as e:
                print(e)
            i+=1
# Out:
# [Errno 2] No such file or directory: './brands_of_the_world/Albania_company_logo/24/7 Rental Cars.jpg'
# [Errno 22] Invalid argument: './brands_of_the_world/Albania_company_logo/Municipality of Pustec (Liqenas) ??????.jpg'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-03e8c43e1648> in <module>
#      24         for image_url in image_url_list:
#      25             try:
# ---> 26                 with urllib.request.urlopen(image_url.get_attribute('src')) as f:
#      27                     with open(img_folder_path + company_name_list[i] +'.jpg','wb') as h:
#      28                         image = f.read()
#
# C:\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# C:\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# C:\anaconda3\lib\urllib\request.py in _open(self, req, data)
#     540
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#     544         if result:
#
# C:\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# C:\anaconda3\lib\urllib\request.py in https_open(self, req)
#    1391
#    1392         def https_open(self, req):
# -> 1393             return self.do_open(http.client.HTTPSConnection, req,
#    1394                 context=self._context, check_hostname=self._check_hostname)
#    1395
#
# C:\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1352             except OSError as err: # timeout error
#    1353                 raise URLError(err)
# -> 1354             r = h.getresponse()
#    1355         except:
#    1356             h.close()
#
# C:\anaconda3\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# C:\anaconda3\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# C:\anaconda3\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# C:\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# C:\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# C:\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## New Code (joowon)

# %%
XPATH_COUNTRY_TABLE = '//*[@id="primaryInner"]/div/div[1]'
XPATH_COUNTRY_NAME = '//*[@id="primary"]/h1/span'

for country_path in country_url_list:
    
    country_name = driver.find_element_by_xpath(XPATH_COUNTRY_NAME)
    img_folder_path = './brands_of_the_world/' + country_name.text + '_company_logo/'
    if(os.path.isdir(img_folder_path) is True):
        continue
    os.makedirs(img_folder_path, exist_ok=True)
    
    page_num = 0
    
    while True:
        # driver.get(country_path + '?page=' + str(page_num))
        driver.get(f'{country_path}?page={page_num}') #f string 
        division = driver.find_element_by_xpath(XPATH_COUNTRY_TABLE) # 빼면 안됨
        name_list = division.find_elements_by_tag_name('li') # List형
        image_url_list = division.find_elements_by_tag_name('img') # List형
            
        if len(image_url_list) == 0: # ['« first', '‹ previous', '1', '2']
            break
        
        for i, image_url in enumerate(image_url_list):
            try:
                with urllib.request.urlopen(image_url.get_attribute('src')) as f:
                    with open(img_folder_path + name_list[i].text +'.jpg','wb') as h:
                        image = f.read()
                        h.write(image)
            except Exception as e:
                print(e)
        page_num +=1
# Out:
# [Errno 2] No such file or directory: './brands_of_the_world/Afghanistan_company_logo/24/7 Rental Cars.jpg'
# [Errno 22] Invalid argument: './brands_of_the_world/Afghanistan_company_logo/Municipality of Pustec (Liqenas) ??????.jpg'
# list index out of range
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# [Errno 22] Invalid argument: './brands_of_the_world/Andorra_company_logo/Duca "Chefe Máquina".jpg'
# [Errno 22] Invalid argument: './brands_of_the_world/Andorra_company_logo/Jandir Talaia "Five".jpg'
# [Errno 22] Invalid argument: './brands_of_the_world/Andorra_company_logo/Helder Coelho "Vuty".jpg'
# [Errno 2] No such file or directory: './brands_of_the_world/Andorra_company_logo/Angola Army/ Exercito Angola.jpg'
# HTTP Error 403: Forbidden
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-271c2dbac04c> in <module>
#      22         for i, image_url in enumerate(image_url_list):
#      23             try:
# ---> 24                 with urllib.request.urlopen(image_url.get_attribute('src')) as f:
#      25                     with open(img_folder_path + name_list[i].text +'.jpg','wb') as h:
#      26                         image = f.read()
#
# C:\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# C:\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# C:\anaconda3\lib\urllib\request.py in _open(self, req, data)
#     540
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#     544         if result:
#
# C:\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# C:\anaconda3\lib\urllib\request.py in https_open(self, req)
#    1391
#    1392         def https_open(self, req):
# -> 1393             return self.do_open(http.client.HTTPSConnection, req,
#    1394                 context=self._context, check_hostname=self._check_hostname)
#    1395
#
# C:\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1352             except OSError as err: # timeout error
#    1353                 raise URLError(err)
# -> 1354             r = h.getresponse()
#    1355         except:
#    1356             h.close()
#
# C:\anaconda3\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# C:\anaconda3\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# C:\anaconda3\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# C:\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# C:\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# C:\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
