# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import pyperclip
import urllib.request
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
path = '/Users/재욱/Downloads/chromedriver'
driver = webdriver.Chrome(path)
xpath = '//*[@id="islrg"]' # xpath는 작은 따옴표로 묶어야함.

search_name = "happyface"

search_url = "https://www.google.com/search?q=" + search_name + "&hl=ko&tbm=isch"
driver.get(search_url)
    
division = driver.find_element_by_xpath(xpath)
img_list = division.find_elements_by_tag_name('img')
img_count = len(img_list)

# %%
from pprint import pprint
for img in img_list:
        pprint(img.get_attribute('src'))
# Out:
# 'data:image/png;base64,...'
# 'data:image/jpeg;base64,...'
# 'data:image/jpeg;base64,...'
# 'data:image/png;base64,...'
# 'data:image/jpeg;base64,...'
# 'data:image/png;base64,...'
# 'data:image/jpeg;base64,...'
# 'data:image/jpeg;base64,...'
# 'data:image/jpeg;base64,...'
# 'data:image/png;base64,...'
# 'data:image/jpeg;base64,...'
# 'data:image/png;base64,...'
# 'data:image/jpeg;base64,...'
# 'data:image/png;base64,...'
# 'data:image/png;base64,...'
# 'data:image/jpeg;base64,...'
# 'data:image/jpeg;base64,...'
# 'data:image/jpeg;base64,...'
# 'data:image/jpeg;base64,...'
# 'data:image/jpeg;base64,...'
# 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRcQpCyZQ9vFt8Cp3kEmb7fxtpcJN1QRa4ym7sz1DI2GZf5YbvWoK3zOH6LP7teZebcNddaPaffLNHXrQ&usqp=CAU'
# 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQI65Xw2qOtnhoJKcK0U-R4zvcjhfh10nXVlkFrgHR_2OOD9AtFCTl6wun7fKlrz8WZh1bkuv1oL1AeMw&usqp=CAU'
# 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ1I4_quZp2lK-mfYFICyB0sDZCOSZ7gIcogAbjfs8Sg0-8B79lcRlztp9dQsRJ6v_TKJHa5ZVbhkNmeg&usqp=CAU'
# 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRk2TMiVu_fF7OHnbqAmtAhRdC6zK8Iyt314O68vRgd_6_rCKpz_9JJSXhqKh1cSP041t7lG0YwybGIpg&usqp=CAU'
# 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcShU1MaPc1CtoMMQhx9PO1ccKJk6G-15ZJJTP_pHzY&usqp=CAU'
# 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ52pgQlWIm94MjsVvqBVFQbEGVIxgHzVz3XlME440&usqp=CAU'
# 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS4Zjd4FlvtQKSWJ7mr5zljd8KXa2H187tObZcrQjc&usqp=CAU'
# 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQT54Q9Ipc6HQAMlEPd9P3h-A-eZEMWtyYFd1gWO5KvC8JKJ8oUHdkm_hPoNe0BRm-O-jkPTXHGPLupRA&usqp=CAU'
# 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQQ3KeCcSK4W1UdrfknsS51b2LNXQLXZT-PPsqNv4DXnU0LS2WB3lrhpN0YDReTQZGZPzMqnROcSIIE9g&usqp=CAU'
# 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRT_sw9Afis513ouLDPWR7-l6xIhVe1Ne73Q8_mW1V952ZcmcUAlVI0q8Xlx5lGBnZMnBnhqeyZCigWEg&usqp=CAU'
# 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRViIwaXzeo6N1my2NfsIa9wbs13IG4RQxRKLj_w6uTCcyXMsO6DO_a9Vo1O3OilZWhw814yZCWBaGB5Q&usqp=CAU'
# 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTMyP-T4CuwAdueDn4fUoeaB-EVlcVBruByeervI3vqrrmiaPYmT0_z75XaM0rPCb6KB3VDge7DgBVU1Q&usqp=CAU'
# 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ3xyCqJLaAfXTQO2rJ1ex5tGpG2hrF9zBR3ZO5YqMKk7bP1OjUDktDDtMX9aHw3FsoJ6jfr-6aaRg_Ag&usqp=CAU'
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQIrvnJnrvYO_Pxf7vH01mUgkJJH8POO2q1U4prlwA&usqp=CAU'
# 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTO5jrgUlJtOpMXtNYR0X8lFCLllVxI0PYZTq-0kLTPw-ItjoGn&usqp=CAU'
# 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSu3wK8_m3_LCn9af4_XMFD7UIMaZowc1BDZ55YXvo&usqp=CAU'

# %%
import os
os.makedirs('./google_img', exist_ok=True)
i = 1

for img in img_list:
    with urllib.request.urlopen(img.get_attribute('src')) as f:
        with open('./google_img/' + str(i) +'.jpg','wb') as h:
            image = f.read()
            h.write(image)
    i+=1
print('Download Completed!')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-0d2e4d7a178b> in <module>
#       4
#       5 for img in img_list:
# ----> 6     with urllib.request.urlopen(img.get_attribute('src')) as f:
#       7         with open('./google_img/' + str(i) +'.jpg','wb') as h:
#       8             image = f.read()
#
# C:\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# C:\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     513                 req.data = data
#     514
# --> 515         req.timeout = timeout
#     516         protocol = req.type
#     517
#
# AttributeError: 'NoneType' object has no attribute 'timeout'

# %%
path = '/Users/재욱/Downloads/chromedriver'
driver = webdriver.Chrome(path)
xpath = "//*[@id="islrg"]"
def search_selenium(search_name, search_num):
    search_url = "https://www.google.com/search?q=" + search_name + "&hl=ko&tbm=isch"
    driver.get(search_url)
    
    division = driver.find_element_by_xpath(xpath)
    img_list = division.find_elements_by_tag_name('img')
    img_count = len(img_list)
    
    for img in img_list:
        print(img.get_attribute('src'))

# %%
if __name__ == "__main__":
    search_name = input("type your keyword : ")
    search_num = int(input("type the number you want to search : "))
    search_path = "my path"
    search_selenium(search_name, search_num)
